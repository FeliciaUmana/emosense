# %%
# ============================================================
# TASK 2: Emotion Recognition from Speech
# ============================================================

import os
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings('ignore')

print("All libraries imported successfully!")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# All libraries imported successfully!
# TensorFlow version: 2.19.0

# %%
import sys
# !{sys.executable} -m pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\hp\anaconda3\lib\site-packages (from resampy) (1.26.4)
# Requirement already satisfied: numba>=0.53 in c:\users\hp\anaconda3\lib\site-packages (from resampy) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\hp\anaconda3\lib\site-packages (from numba>=0.53->resampy) (0.43.0)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.1 MB 1.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.3/3.1 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.6/3.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 3.8 MB/s eta 0:00:00
# Installing collected packages: resampy
# Successfully installed resampy-0.4.3

# %%
# ============================================================
# Stage 2 — Load RAVDESS dataset and extract MFCC features
# ============================================================

# Correct path to your RAVDESS dataset folder
DATASET_PATH = r"C:\Users\HP\Desktop\Emotion Recognition\archive (8)\audio_speech_actors_01-24"

# RAVDESS emotion labels from filename
emotion_map = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

def extract_mfcc(file_path, n_mfcc=40):
    """Extract MFCC features from an audio file"""
    audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    mfccs_scaled = np.mean(mfccs.T, axis=0)
    return mfccs_scaled

# Load all files and extract features
features = []
labels = []

print("Loading audio files and extracting features...")

for actor_folder in os.listdir(DATASET_PATH):
    actor_path = os.path.join(DATASET_PATH, actor_folder)
    if os.path.isdir(actor_path):
        for file in os.listdir(actor_path):
            if file.endswith('.wav'):
                file_path = os.path.join(actor_path, file)
                emotion_code = file.split('-')[2]
                if emotion_code in emotion_map:
                    try:
                        mfcc = extract_mfcc(file_path)
                        features.append(mfcc)
                        labels.append(emotion_map[emotion_code])
                    except Exception as e:
                        print(f"Error processing {file}: {e}")

print(f"Total files processed: {len(features)}")
print(f"Emotions found: {set(labels)}")
# Out:
# Loading audio files and extracting features...
# Total files processed: 1440
# Emotions found: {'calm', 'happy', 'fearful', 'neutral', 'disgust', 'angry', 'sad', 'surprised'}

# %%
# ============================================================
# Stage 3 — Prepare the data for training
# ============================================================

# Convert to numpy arrays
X = np.array(features)
y = np.array(labels)

print(f"Features shape: {X.shape}")
print(f"Labels shape: {y.shape}")

# Encode emotion labels to numbers
le = LabelEncoder()
y_encoded = le.fit_transform(y)
print(f"\nEmotion classes: {le.classes_}")
print(f"Encoded labels sample: {y_encoded[:10]}")

# Normalize features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reshape for CNN+LSTM (samples, timesteps, features)
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)
print(f"\nReshaped features: {X_reshaped.shape}")

# Convert labels to one-hot encoding
y_categorical = to_categorical(y_encoded)
print(f"Categorical labels shape: {y_categorical.shape}")

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, y_categorical, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"\nTraining samples: {X_train.shape[0]}")
print(f"Testing samples:  {X_test.shape[0]}")
print("\nData preparation complete!")
# Out:
# Features shape: (1440, 40)
# Labels shape: (1440,)
#
# Emotion classes: ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']
# Encoded labels sample: [5 5 5 5 1 1 1 1 1 1]
#
# Reshaped features: (1440, 40, 1)
# Categorical labels shape: (1440, 8)
#
# Training samples: 1152
# Testing samples:  288
#
# Data preparation complete!

# %%
# ============================================================
# Stage 4 — Build and Train CNN + LSTM Model
# ============================================================

model = Sequential([
    # CNN layers to extract local features
    Conv1D(64, kernel_size=3, activation='relu', input_shape=(40, 1)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Conv1D(128, kernel_size=3, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    # LSTM layer to learn temporal patterns
    LSTM(64, return_sequences=False),
    Dropout(0.3),

    # Output layers
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(8, activation='softmax')  # 8 emotions
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5185 - loss: 1.3018 - val_accuracy: 0.4132 - val_loss: 1.6110 - learning_rate: 0.0010
# Epoch 29/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5088 - loss: 1.3069 - val_accuracy: 0.4653 - val_loss: 1.6655 - learning_rate: 0.0010
# Epoch 30/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5023 - loss: 1.3030 - val_accuracy: 0.4618 - val_loss: 1.5802 - learning_rate: 0.0010
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5319 - loss: 1.2981 - val_accuracy: 0.4653 - val_loss: 1.6027 - learning_rate: 0.0010
# Epoch 32/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5371 - loss: 1.2134 - val_accuracy: 0.4514 - val_loss: 1.5755 - learning_rate: 0.0010
# Epoch 33/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5553 - loss: 1.1847 - val_accuracy: 0.4375 - val_loss: 1.5891 - learning_rate: 0.0010
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5887 - loss: 1.1691 - val_accuracy: 0.4653 - val_loss: 1.6236 - learning_rate: 0.0010
# Epoch 35/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5727 - loss: 1.2069 - val_accuracy: 0.4306 - val_loss: 1.6218 - learning_rate: 0.0010
# Epoch 36/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5921 - loss: 1.1049 - val_accuracy: 0.4514 - val_loss: 1.5377 - learning_rate: 0.0010
# Epoch 37/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5518 - loss: 1.1522 - val_accuracy: 0.4549 - val_loss: 1.6236 - learning_rate: 0.0010
# Epoch 38/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6247 - loss: 1.0389 - val_accuracy: 0.4479 - val_loss: 1.5794 - learning_rate: 0.0010
# Epoch 39/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6203 - loss: 1.0621 - val_accuracy: 0.4583 - val_loss: 1.6086 - learning_rate: 0.0010
# Epoch 40/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6169 - loss: 1.0435 - val_accuracy: 0.4444 - val_loss: 1.6462 - learning_rate: 0.0010
# Epoch 41/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6145 - loss: 1.0033 - val_accuracy: 0.4583 - val_loss: 1.5896 - learning_rate: 0.0010
# Epoch 42/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6427 - loss: 0.9619 - val_accuracy: 0.4792 - val_loss: 1.5993 - learning_rate: 5.0000e-04
# Epoch 43/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6348 - loss: 1.0329 - val_accuracy: 0.4653 - val_loss: 1.5743 - learning_rate: 5.0000e-04
# Epoch 44/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6744 - loss: 0.9028 - val_accuracy: 0.4757 - val_loss: 1.6059 - learning_rate: 5.0000e-04
# Epoch 45/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7020 - loss: 0.8567 - val_accuracy: 0.4757 - val_loss: 1.5828 - learning_rate: 5.0000e-04
# Epoch 46/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6427 - loss: 0.9347 - val_accuracy: 0.4896 - val_loss: 1.6224 - learning_rate: 5.0000e-04
#
# Training complete!

# %%
# ============================================================
# Stage 5 — Evaluate the model
# ============================================================

# Test accuracy
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")

# Predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Classification report
print("\nClassification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=le.classes_))

# Confusion matrix
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix - Emotion Recognition')
plt.ylabel('True Emotion')
plt.xlabel('Predicted Emotion')
plt.tight_layout()
plt.savefig('confusion_matrix.png')
plt.show()
print("\nConfusion matrix saved!")

# ============================================================
# Stage 6 — Save the model and scaler
# ============================================================
import joblib

model.save('emotion_model.h5')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(le, 'label_encoder.pkl')

print("\nModel saved as emotion_model.h5")
print("Scaler saved as scaler.pkl")
print("Label encoder saved as label_encoder.pkl")
# Out:
# Test Accuracy: 45.14%
# Test Loss: 1.5377
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.72      0.55      0.63        38
#         calm       0.50      0.74      0.60        38
#      disgust       0.42      0.45      0.44        38
#      fearful       0.53      0.54      0.53        39
#        happy       0.38      0.21      0.27        39
#      neutral       0.22      0.11      0.14        19
#          sad       0.17      0.24      0.20        38
#    surprised       0.59      0.62      0.60        39
#
#     accuracy                           0.45       288
#    macro avg       0.44      0.43      0.42       288
# weighted avg       0.46      0.45      0.44       288
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Confusion matrix saved!
#
# Model saved as emotion_model.h5
# Scaler saved as scaler.pkl
# Label encoder saved as label_encoder.pkl

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.legend()

plt.savefig('training_history.png')
plt.show()
